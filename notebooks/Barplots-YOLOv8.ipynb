# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from PIL import Image
import cv2
import json
import sys
import easyocr
import os
from shutil import move, copy
from ultralytics import YOLO
sys.path.append('../src')

# %load_ext autoreload
# %autoreload 2
from extract_data.barplots import detect_graph_space
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../data/interim/annots_imgs_merged.csv')
bar = df[df['chart-type'] == 'vertical_bar']
bar = bar[['chart-type','data-series','visual-elements.bars','file_name', 'image_path']]
bar = bar.reset_index(drop=True)
bar.columns = ['type','data_series','data','name','path']
bar.head()
# Out:
#            type                                        data_series  \
# 0  vertical_bar  [{'x': 'Jordan', 'y': 88.35159235668789}, {'x'...
# 1  vertical_bar  [{'x': 'Cuba', 'y': 75695.38632268383}, {'x': ...
# 2  vertical_bar  [{'x': 'Jamaica', 'y': 36.43411033235605}, {'x...
# 3  vertical_bar  [{'x': '1', 'y': 62.45402663284719}, {'x': '2'...
# 4  vertical_bar  [{'x': 'Harney', 'y': 75.91000641635438}, {'x'...
#
#                                                 data          name  \
# 0  [{'height': 103, 'width': 19, 'x0': 77, 'y0': ...  75c0449f6917
# 1  [{'height': 124, 'width': 12, 'x0': 104, 'y0':...  58595c30beab
# 2  [{'height': 75, 'width': 21, 'x0': 62, 'y0': 9...  5022600d52d7
# 3  [{'height': 187, 'width': 11, 'x0': 60, 'y0': ...  32176a89b822
# 4  [{'height': 167, 'width': 14, 'x0': 71, 'y0': ...  3d895e511690
#
#                                         path
# 0  ../data/raw/train/images/75c0449f6917.jpg
# 1  ../data/raw/train/images/58595c30beab.jpg
# 2  ../data/raw/train/images/5022600d52d7.jpg
# 3  ../data/raw/train/images/32176a89b822.jpg
# 4  ../data/raw/train/images/3d895e511690.jpg

# %%
bar_samples = bar.head(500)

dataframes = []
for i in range(len(bar_samples)):
    # extract xy coordinates from data_coords column
    coords = bar_samples['data'][i]
    coords = coords.replace("'", "\"")
    coords_list = json.loads(coords)

    # extract important image info
    path = bar_samples['path'][i]
    name = bar_samples['name'][i]
    img = cv2.imread(path)
    height = img.shape[0]
    width = img.shape[1]

    # Save the xy coords into a list
    bbox = []
    for data in coords_list:

        x1 = data['x0']
        y1= data['y0']
        w = data['width']
        h = data['height']
        x2 = x1 + w
        y2 = y1 + h

        x_center = (x1+x2)/(2*width)
        y_center = (y1+y2)/(2*height)
        yolo_width = w/width
        yolo_height = h/height
        bbox.append((x_center, y_center, yolo_width, yolo_height))
  
   

    # Save into list of dataframe
    yolo = pd.DataFrame(bbox, columns=['x','y','w','h'])
    yolo['class'] = 0
    yolo['path'] = path
    yolo['name'] = name
    yolo = yolo[['path','name','class','x','y','w','h']]
    dataframes.append(yolo)

# Concat dataframes and check that the number of unique images is correct
yolo_df = pd.concat(dataframes)
yolo_df['path'].nunique()
# Out:
# 500

# %%
yolo_df
# Out:
#                                          path          name  class         x  \
# 0   ../data/raw/train/images/75c0449f6917.jpg  75c0449f6917      0  0.184829
# 1   ../data/raw/train/images/75c0449f6917.jpg  75c0449f6917      0  0.268162
# 2   ../data/raw/train/images/75c0449f6917.jpg  75c0449f6917      0  0.351496
# 3   ../data/raw/train/images/75c0449f6917.jpg  75c0449f6917      0  0.434829
# 4   ../data/raw/train/images/75c0449f6917.jpg  75c0449f6917      0  0.518162
# ..                                        ...           ...    ...       ...
# 8   ../data/raw/train/images/b38361166664.jpg  b38361166664      0  0.682900
# 9   ../data/raw/train/images/b38361166664.jpg  b38361166664      0  0.748918
# 10  ../data/raw/train/images/b38361166664.jpg  b38361166664      0  0.816017
# 11  ../data/raw/train/images/b38361166664.jpg  b38361166664      0  0.882035
# 12  ../data/raw/train/images/b38361166664.jpg  b38361166664      0  0.948052
#
#            y         w         h
# 0   0.534173  0.040598  0.370504
# 1   0.485612  0.040598  0.467626
# 2   0.579137  0.040598  0.280576
# 3   0.669065  0.040598  0.100719
# 4   0.505396  0.040598  0.428058
# ..       ...       ...       ...
# 8   0.723183  0.015152  0.221453
# 9   0.536332  0.017316  0.595156
# 10  0.527682  0.017316  0.612457
# 11  0.607266  0.015152  0.453287
# 12  0.508651  0.017316  0.650519
#
# [6278 rows x 7 columns]

# %%
unique_images = yolo_df['path'].unique()
img_df = pd.DataFrame(unique_images,columns=['path'])
img_train = tuple(img_df.sample(frac=0.8)['path'])
img_test = tuple(img_df.query(f'path not in {img_train}')['path'])
len(img_train), len(img_test)
# Out:
# (400, 100)

# %%
train_df = yolo_df.query(f'path in {img_train}')
test_df = yolo_df.query(f'path in {img_test}')

# %%
src_folder = '../data/raw/train/images/'
train_folder = '../data/processed/YOLO/Barplots/train/'
test_folder = '../data/processed/YOLO/Barplots/test/'

# %%
cols = ['name','class','x','y','w','h']
groupby_obj_train = train_df[cols].groupby('name')
groupby_obj_test = test_df[cols].groupby('name')

# %%
def save_data(filename, folder_path, group_obj):
    #copy image
    src = os.path.join(src_folder,filename)+'.jpg'
    dst = os.path.join(folder_path, filename)+'.jpg'
    copy(src, dst)

    #save labels
    text_filename = os.path.join(folder_path,filename+'.txt')
    group_obj.get_group(filename).set_index('name').to_csv(text_filename, index=False, header=False, sep=' ')

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())
filename_series.apply(save_data,args=(train_folder, groupby_obj_train))
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 395    None
# 396    None
# 397    None
# 398    None
# 399    None
# Length: 400, dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder, groupby_obj_test))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 95    None
# 96    None
# 97    None
# 98    None
# 99    None
# Length: 100, dtype: object

# %%
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients

# %%
model.train(data = '../data/processed/YOLO/Barplots/data.yaml', epochs=50)
# Out:
# New https://pypi.org/project/ultralytics/8.0.132 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.124 🚀 Python-3.11.3 torch-2.0.1 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=../data/processed/YOLO/Barplots/data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3011043 parameters, 3011027 gradients
#
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# train: Scanning /Users/matt/Desktop/graphs-capstone/data/processed/YOLO/Barplots/train.cache... 400 images, 0 backgrounds, 1 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
# train: WARNING ⚠️ /Users/matt/Desktop/graphs-capstone/data/processed/YOLO/Barplots/train/9d6c4b6dce0d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0175]
# val: Scanning /Users/matt/Desktop/graphs-capstone/data/processed/YOLO/Barplots/test.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      6.213      4.095      4.102        289        640: 100%|██████████| 25/25 [08:41<00:00, 20.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.51s/it]
#                    all        100       1282          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      4.523      2.435      3.436        337        640: 100%|██████████| 25/25 [07:37<00:00, 18.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.39s/it]
#                    all        100       1282          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      3.491      1.786      2.758        393        640: 100%|██████████| 25/25 [07:06<00:00, 17.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.50s/it]
#                    all        100       1282   0.000235    0.00468   0.000534   0.000146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      2.894      1.633      2.408        321        640: 100%|██████████| 25/25 [07:55<00:00, 19.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:23<00:00,  5.89s/it]
#                    all        100       1282      0.526      0.417      0.425      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      2.614      1.476      2.228        301        640: 100%|██████████| 25/25 [07:26<00:00, 17.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.61s/it]
#                    all        100       1282      0.746      0.659      0.692      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      2
59s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.70s/it]
#                    all        100       1282      0.975      0.883      0.911      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G      1.144     0.6516      1.159        387        640: 100%|██████████| 25/25 [07:30<00:00, 18.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.47s/it]
#                    all        100       1282      0.972      0.891      0.911      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G      1.199     0.6748      1.152        330        640: 100%|██████████| 25/25 [06:22<00:00, 15.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.41s/it]
#                    all        100       1282      0.985      0.895      0.913      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G      1.169     0.6664       1.13        303        640: 100%|██████████| 25/25 [06:25<00:00, 15.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.43s/it]
#                    all        100       1282      0.987      0.894      0.913      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G      1.169     0.6655      1.143        262        640: 100%|██████████| 25/25 [07:01<00:00, 16.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.48s/it]
#                    all        100       1282       0.99      0.889      0.915      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G      1.138     0.6508      1.106        299        640: 100%|██████████| 25/25 [06:29<00:00, 15.59s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.47s/it]
#                    all        100       1282      0.983      0.895      0.915      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G      1.136     0.6448      1.116        304        640: 100%|██████████| 25/25 [07:24<00:00, 17.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.45s/it]
#                    all        100       1282      0.996       0.89      0.913      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G      1.138     0.6388      1.099        290        640: 100%|██████████| 25/25 [06:52<00:00, 16.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.35s/it]
#                    all        100       1282      0.994      0.899      0.916      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G      1.104     0.6249      1.092        332        640: 100%|██████████| 25/25 [06:54<00:00, 16.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.58s/it]
#                    all        100       1282       0.99       0.89      0.914      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G      1.134     0.6253       1.09        289        640: 100%|██████████| 25/25 [07:28<00:00, 17.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.49s/it]
#                    all        100       1282      0.985      0.897      0.915      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G      1.101     0.6159      1.076        397        640: 100%|██████████| 25/25 [07:07<00:00, 17.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.45s/it]
#                    all        100       1282      0.993      0.901      0.917      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G      1.114     0.6129      1.067        339        640: 100%|██████████| 25/25 [07:11<00:00, 17.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.55s/it]
#                    all        100       1282       0.99      0.899      0.914      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      1.111     0.6212      1.062        337        640: 100%|██████████| 25/25 [06:35<00:00, 15.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.52s/it]
#                    all        100       1282      0.992      0.902      0.918      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G      1.096     0.6085       1.06        291        640: 100%|██████████| 25/25 [07:14<00:00, 17.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:21<00:00,  5.50s/it]
#                    all        100       1282      0.994      0.899      0.916      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G      1.079     0.5929      1.047        277        640: 100%|██████████| 25/25 [07:14<00:00, 17.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.54s/it]
#                    all        100       1282      0.989      0.899       0.91       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G      1.092     0.6083      1.053        319        640: 100%|██████████| 25/25 [07:22<00:00, 17.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.69s/it]
#                    all        100       1282       0.99      0.897      0.914      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G      1.086     0.6071      1.056        278        640: 100%|██████████| 25/25 [07:25<00:00, 17.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.63s/it]
#                    all        100       1282      0.992      0.899       0.91      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G      1.045     0.5868      1.041        345        640: 100%|██████████| 25/25 [11:47<00:00, 28.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:34<00:00,  8.74s/it]
#                    all        100       1282      0.992      0.898      0.917      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G      1.094     0.5996      1.042        217        640: 100%|██████████| 25/25 [11:29<00:00, 27.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:32<00:00,  8.15s/it]
#                    all        100       1282      0.994        0.9      0.918      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G      1.082     0.6038      1.036        351        640: 100%|██████████| 25/25 [09:50<00:00, 23.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.57s/it]
#                    all        100       1282      0.989      0.902      0.917       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      1.087     0.5977       1.04        303        640: 100%|██████████| 25/25 [08:00<00:00, 19.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.62s/it]
#                    all        100       1282      0.994      0.904      0.918      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      1.061     0.5872      1.031        274        640: 100%|██████████| 25/25 [08:22<00:00, 20.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:38<00:00,  9.66s/it]
#                    all        100       1282      0.992      0.903      0.917      0.666
#
# 50 epochs completed in 6.763 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 6.2MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.124 🚀 Python-3.11.3 torch-2.0.1 CPU
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:30<00:00,  7.56s/it]
#                    all        100       1282      0.992      0.897      0.917      0.697
# Speed: 7.8ms preprocess, 264.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/train2

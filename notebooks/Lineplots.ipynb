# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import json

# %%
df = pd.read_csv('../data/interim/annots_imgs_merged.csv')
line = df[df['chart-type'] == 'line']
line = line[['chart-type','data-series','visual-elements.lines','file_name', 'image_path']]
line = line.reset_index(drop=True)
line.columns = ['type','data_series','data','name','path']
line.head()
# Out:
#    type                                        data_series  \
# 0  line  [{'x': 'Afghanistan', 'y': 97.39144067786003},...
# 1  line  [{'x': '1990', 'y': 460139.397945082}, {'x': '...
# 2  line  [{'x': '0', 'y': 20.138269927536232}, {'x': '2...
# 3  line  [{'x': 'United Kingdom', 'y': 312370881.669299...
# 4  line  [{'x': 'Lithuania', 'y': 25.360055676098174}, ...
#
#                                                 data          name  \
# 0  [[{'x': 79.0, 'y': 118.98393922747988}, {'x': ...  a2858b17f9de
# 1  [[{'x': 112.66666666666667, 'y': 116.484848484...  2208375c43e9
# 2  [[{'x': 205.33333333333334, 'y': 270.077777777...  49e8a20490e8
# 3  [[{'x': 92.0, 'y': 130.25}, {'x': 130.5, 'y': ...  bb52cf8971a1
# 4  [[{'x': 86.66666666666667, 'y': 201.8333333333...  edf075ca7f11
#
#                                         path
# 0  ../data/raw/train/images/a2858b17f9de.jpg
# 1  ../data/raw/train/images/2208375c43e9.jpg
# 2  ../data/raw/train/images/49e8a20490e8.jpg
# 3  ../data/raw/train/images/bb52cf8971a1.jpg
# 4  ../data/raw/train/images/edf075ca7f11.jpg

# %%
path = line['path'].values[0]
img = cv2.imread(path)
plt.imshow(img)
plt.show()
